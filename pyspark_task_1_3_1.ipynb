# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from datetime import date, datetime

spark = SparkSession.builder \
        .appName('betera_task') \
        .getOrCreate()

# %%
df_bets = spark.read.csv('data/bets.csv', header = True, inferSchema = True)
df_events = spark.read.csv('data/events.csv', header = True, inferSchema = True)

# %%
bad_bets = df_bets.join(df_events, "event_id" how = 'inner') \
    .filter(F.col("event_stage") != "Prematch" |

)
